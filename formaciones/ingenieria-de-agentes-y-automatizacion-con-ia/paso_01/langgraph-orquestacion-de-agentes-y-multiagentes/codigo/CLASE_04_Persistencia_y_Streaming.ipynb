# %%
# %pip install -qU langgraph langchain langchain-google-genai langchain-tavily python-dotenv aiosqlite langgraph-checkpoint-sqlite
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()

GEMINI_API_KEY = os.getenv('GEMINI_API_KEY') 
TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')

# %%
import operator
from typing import Annotated, List, Any, Dict
from dataclasses import dataclass, field
from langgraph.graph import StateGraph, END
from langchain_core.messages import HumanMessage, SystemMessage, ToolMessage, BaseMessage, AnyMessage
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_tavily import TavilySearch
from langgraph.checkpoint.sqlite import SqliteSaver
from typing_extensions import TypedDict
import sqlite3

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

conn = sqlite3.connect("checkpoints.db", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        
        graph = StateGraph(AgentState)

        graph.add_node("llm", self.call_gemini)

        graph.add_node("action", self.take_action)

        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})

        graph.add_edge("action", "llm")

        graph.set_entry_point("llm")

        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_gemini(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages

        print("Mensajes enviados al modelo:", messages)
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Llamando la Herramienta: {t['name']} con los siguientes argumentos: {t['args']}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Retornando a la LLM tras la acción!")
        return {'messages': results}

# %%
# current_tavily_api_key = os.getenv('TAVILY_API_KEY')
if not TAVILY_API_KEY:
    raise ValueError("TAVILY_API_KEY não encontrada. Certifique-se de que está no seu .env e python-dotenv está instalado.")

tool = TavilySearch(max_results=3, tavily_api_key=TAVILY_API_KEY)


prompt_system = """
Eres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.
Tienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).
Busca información únicamente cuando tengas certeza de qué buscar.
Si necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.
Cuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.
"""

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite") 

abot = Agent(model, [tool], system=prompt_system, checkpointer=memory)

# %%
messages = [HumanMessage(content="Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?")]
thread = {"configurable": {"thread_id": "3"}} 


print("\n--- Pregunta 1: Clima en Lima ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"): 
             print(f"{k}: {v['messages']}")
# Out:
# --- Pregunta 1: Clima en Lima ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={})]
# llm: [AIMessage(content=[], additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa 29 de diciembre 2025"}'}, '__gemini_function_call_thought_signatures__': {'SbhlQnyt': 'EjQKMgERTTIP9tWrltwwAGWuEO32tsajxKkkoiRcov5g7uyJTIoJ/uJ7BK9cQ3UN4wbyKDRs'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfa-2239-7603-b044-da7d97aeb1d8-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú 29 de diciembre 2025'}, 'id': 'SbhlQnyt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1647, 'output_tokens': 32, 'total_tokens': 1679, 'input_token_details': {'cache_read': 0}})]
# Llamando la Herramienta: tavily_search con los siguientes argumentos: {'query': 'clima en Lima Perú 29 de diciembre 2025'}
# Retornando a la LLM tras la acción!
# action: [ToolMessage(content="{'query': 'clima en Lima Perú 29 de diciembre 2025', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.am1010ondalatina.com/articulo/2025/12/clima-hoy-en-lima-peru-el-pronostico-del-tiempo-para-este-lunes-29-diciembre-de-2025.php', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025 - Onda Latina AM 1010', 'content': '## Último Momento :. ## Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025. El pronóstico extendido durante la jornada.¿Cómo estará el cielo? ¿Cuál es la probabilidad de lluvias?... * 📘 Compartir en Facebook 🐦 Compartir en Twitter 💬 Compartir por WhatsApp 🔗 Copiar enlace. ### Comentarios. ### Deja tu comentario. ## Más Populares. ## 🔔 ¡Activa las Notificaciones! Mantente informado con las últimas novedades.', 'score': 0.90227455, 'raw_content': None}, {'url': 'https://rpp.pe/peru/actualidad/senamhi-pronostico-del-clima-hoy-lunes-29-de-diciembre-2025-noticia-1669539', 'title': 'SENAMHI: Pronóstico del clima hoy lunes 29 de diciembre 2025', 'content': 'Consulta el pronóstico del clima hoy en Lima y ciudades del Perú: temperatura actual, sensación térmica, radiación UV, probabilidad de lluvia y', 'score': 0.82492816, 'raw_content': None}, {'url': 'https://www.clarin.com/informacion-general/clima-hoy-lima-peru-pronostico-tiempo-lunes-29-diciembre-2025_0_HLjQ5uUfRs.html', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes ...', 'content': 'El pronóstico del tiempo para Lima, Perú indica que este lunes 29 de diciembre la temperatura máxima será de 24°C y la mínima de 18°C.', 'score': 0.8194462, 'raw_content': None}], 'response_time': 0.88, 'request_id': '22a8f2fa-7d71-456b-b018-3819630c2411'}", name='tavily_search', tool_call_id='SbhlQnyt')]
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content=[], additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa 29 de diciembre 2025"}'}, '__gemini_function_call_thought_signatures__': {'SbhlQnyt': 'EjQKMgERTTIP9tWrltwwAGWuEO32tsajxKkkoiRcov5g7uyJTIoJ/uJ7BK9cQ3UN4wbyKDRs'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfa-2239-7603-b044-da7d97aeb1d8-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú 29 de diciembre 2025'}, 'id': 'SbhlQnyt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1647, 'output_tokens': 32, 'total_tokens': 1679, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'clima en Lima Perú 29 de diciembre 2025', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.am1010ondalatina.com/articulo/2025/12/clima-hoy-en-lima-peru-el-pronostico-del-tiempo-para-este-lunes-29-diciembre-de-2025.php', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025 - Onda Latina AM 1010', 'content': '## Último Momento :. ## Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025. El pronóstico extendido durante la jornada.¿Cómo estará el cielo? ¿Cuál es la probabilidad de lluvias?... * 📘 Compartir en Facebook 🐦 Compartir en Twitter 💬 Compartir por WhatsApp 🔗 Copiar enlace. ### Comentarios. ### Deja tu comentario. ## Más Populares. ## 🔔 ¡Activa las Notificaciones! Mantente informado con las últimas novedades.', 'score': 0.90227455, 'raw_content': None}, {'url': 'https://rpp.pe/peru/actualidad/senamhi-pronostico-del-clima-hoy-lunes-29-de-diciembre-2025-noticia-1669539', 'title': 'SENAMHI: Pronóstico del clima hoy lunes 29 de diciembre 2025', 'content': 'Consulta el pronóstico del clima hoy en Lima y ciudades del Perú: temperatura actual, sensación térmica, radiación UV, probabilidad de lluvia y', 'score': 0.82492816, 'raw_content': None}, {'url': 'https://www.clarin.com/informacion-general/clima-hoy-lima-peru-pronostico-tiempo-lunes-29-diciembre-2025_0_HLjQ5uUfRs.html', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes ...', 'content': 'El pronóstico del tiempo para Lima, Perú indica que este lunes 29 de diciembre la temperatura máxima será de 24°C y la mínima de 18°C.', 'score': 0.8194462, 'raw_content': None}], 'response_time': 0.88, 'request_id': '22a8f2fa-7d71-456b-b018-3819630c2411'}", name='tavily_search', tool_call_id='SbhlQnyt')]
# llm: [AIMessage(content=[{'type': 'text', 'text': 'Para hoy, lunes 29 de diciembre de 2025, el pronóstico del tiempo en Lima, Perú, indica temperaturas moderadas propias de la temporada:\n\n*   **Temperatura máxima:** 24°C\n*   **Temperatura mínima:** 18°C\n\nSe recomienda estar atento a los reportes del SENAMHI durante el día para conocer variaciones en la radiación UV o condiciones específicas de nubosidad, que son habituales en la capital peruana durante esta época.', 'extras': {'signature': 'EjQKMgERTTIPRlgwdJb0oli9UE1icfRjPGOI6RvYvhNcHDtCS9ferBDhM5u84hrfTvpzKAvg'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfa-2e21-7281-9800-af0a6b790a3b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2328, 'output_tokens': 105, 'total_tokens': 2433, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Y el clima en Medellín?")]
thread = {"configurable": {"thread_id": "3"}} 

print("\n--- Pregunta 2: Clima en Medellín ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pregunta 2: Clima en Medellín ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content=[], additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa 29 de diciembre 2025"}'}, '__gemini_function_call_thought_signatures__': {'SbhlQnyt': 'EjQKMgERTTIP9tWrltwwAGWuEO32tsajxKkkoiRcov5g7uyJTIoJ/uJ7BK9cQ3UN4wbyKDRs'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfa-2239-7603-b044-da7d97aeb1d8-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú 29 de diciembre 2025'}, 'id': 'SbhlQnyt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1647, 'output_tokens': 32, 'total_tokens': 1679, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'clima en Lima Perú 29 de diciembre 2025', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.am1010ondalatina.com/articulo/2025/12/clima-hoy-en-lima-peru-el-pronostico-del-tiempo-para-este-lunes-29-diciembre-de-2025.php', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025 - Onda Latina AM 1010', 'content': '## Último Momento :. ## Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025. El pronóstico extendido durante la jornada.¿Cómo estará el cielo? ¿Cuál es la probabilidad de lluvias?... * 📘 Compartir en Facebook 🐦 Compartir en Twitter 💬 Compartir por WhatsApp 🔗 Copiar enlace. ### Comentarios. ### Deja tu comentario. ## Más Populares. ## 🔔 ¡Activa las Notificaciones! Mantente informado con las últimas novedades.', 'score': 0.90227455, 'raw_content': None}, {'url': 'https://rpp.pe/peru/actualidad/senamhi-pronostico-del-clima-hoy-lunes-29-de-diciembre-2025-noticia-1669539', 'title': 'SENAMHI: Pronóstico del clima hoy lunes 29 de diciembre 2025', 'content': 'Consulta el pronóstico del clima hoy en Lima y ciudades del Perú: temperatura actual, sensación térmica, radiación UV, probabilidad de lluvia y', 'score': 0.82492816, 'raw_content': None}, {'url': 'https://www.clarin.com/informacion-general/clima-hoy-lima-peru-pronostico-tiempo-lunes-29-diciembre-2025_0_HLjQ5uUfRs.html', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes ...', 'content': 'El pronóstico del tiempo para Lima, Perú indica que este lunes 29 de diciembre la temperatura máxima será de 24°C y la mínima de 18°C.', 'score': 0.8194462, 'raw_content': None}], 'response_time': 0.88, 'request_id': '22a8f2fa-7d71-456b-b018-3819630c2411'}", name='tavily_search', tool_call_id='SbhlQnyt'), AIMessage(content=[{'type': 'text', 'text': 'Para hoy, lunes 29 de diciembre de 2025, el pronóstico del tiempo en Lima, Perú, indica temperaturas moderadas propias de la temporada:\n\n*   **Temperatura máxima:** 24°C\n*   **Temperatura mínima:** 18°C\n\nSe recomienda estar atento a los reportes del SENAMHI durante el día para conocer variaciones en la radiación UV o condiciones específicas de nubosidad, que so ...
# llm: [AIMessage(content=[], additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Medell\\u00edn hoy 29 de diciembre 2025"}'}, '__gemini_function_call_thought_signatures__': {'FfNVM93c': 'EjQKMgERTTIPFE6qQZuHrkqXmCfcmBAjtarrf2IvF0aRH7LbgMEYwA+8rHVph1Ho19zHZAIZ'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfb-7ed0-75e2-82e6-a41fc366fb01-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Medellín hoy 29 de diciembre 2025'}, 'id': 'FfNVM93c', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2441, 'output_tokens': 32, 'total_tokens': 2473, 'input_token_details': {'cache_read': 0}})]
# Llamando la Herramienta: tavily_search con los siguientes argumentos: {'query': 'clima en Medellín hoy 29 de diciembre 2025'}
# Retornando a la LLM tras la acción!
# action: [ToolMessage(content="{'query': 'clima en Medellín hoy 29 de diciembre 2025', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.clarin.com/informacion-general/clima-hoy-medellin-colombia-pronostico-tiempo-lunes-29-diciembre-2025_0_kkBSRS8NJs.html', 'title': 'Clima hoy en Medellín, Colombia: el pronóstico del tiempo ...', 'content': 'El pronóstico del tiempo para Medellín, Colombia indica que este lunes 29 de diciembre la temperatura máxima será de 26°C y la mínima de', 'score': 0.8674071, 'raw_content': None}, {'url': 'https://es.climate-data.org/america-del-sur/colombia/antioquia/medellin-4088/t/diciembre-12', 'title': 'Clima en Medellín en diciembre 2026: temperatura y clima', 'content': '# Tiempo en Medellín en diciembre. ## El tiempo en Medellín durante diciembre. |  | Temperatura diciembre | 15.6°C |  | Precipitación / Lluvia diciembre | 203mm |. |  | Temperatura diciembre | 15.6°C |. En Medellín, el día más cálido de diciembre es 23.12, con temperaturas que alcanzan 23.7°C. En el primer tercio del mes, las máximas promedian 22.9°C, mientras que las mínimas rondan 14.7°C. En el tercio medio, las máximas alcanzan 22.9°C y las mínimas se sitúan en 14.6°C. El día con más sol es 28.12, con 7 horas, mientras que 18.12 es el más nublado, con 5 horas. Durante el primer tercio del mes, la insolación media es de 6 horas, aumenta a 6 horas a mediados de mes y termina con 7 horas. El mayor volumen de lluvia en un periodo de 10 días se registra entre 1-10, con 3 mm, mientras que el tramo más seco se da entre 11-20, con tan solo 0.7 mm.', 'score': 0.78473216, 'raw_content': None}, {'url': 'https://www.tiempo3.com/south-america/colombia/sucre/medellin?page=month&month=December', 'title': 'Clima en Medellin en diciembre 2026 | Tiempo3.com', 'content': '# Pronóstico meteorológico del clima en Medellin para diciembre de 2026. Durante el mes de diciembre 2026, Medellin experimentará **temperaturas mínimas de 11°C y máximas de hasta 22°C.**. Habrá muchos días de lluvia durante el mes de diciembre en Medellin. Se espera un promedio de **15 a 22 días de lluvia en Medellin**, así que asegúrate de salir de casa con un buen chubasquero. | 1 Niebla moderada 23° /9° | 2 Ligeras precipitaciones 23° /12° | 3 Lluvias fuertes o moderadas 21° /10° | 4 Ligeras precipitaciones 22° /10° | 5 Ligeras precipitaciones 22° /11° |. | 20 Niebla moderada 22° /10° | 21 Ligeras precipitaciones 22° /9° | 22 Ligeras precipitaciones 20° /10° | 23 Ligeras precipitaciones 21° /10° | 24 Ligeras precipitaciones 21° /10° | 25 Lluvias fuertes o moderadas 21° /9° | 26 Intervalos de lluvias ligeras con tomenta en la región 21° /9° |. El clima de Medellin en diciembre es agradable.', 'score': 0.75377536, 'raw_content': None}], 'response_time': 1.49, 'request_id': 'eaef182e-4102-43a5-b6f6-01f066ce1a9b'}", name='tavily_search', tool_call_id='FfNVM93c')]
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content=[], additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa 29 de diciembre 2025"}'}, '__gemini_function_call_thought_signatures__': {'SbhlQnyt': 'EjQKMgERTTIP9tWrltwwAGWuEO32tsajxKkkoiRcov5g7uyJTIoJ/uJ7BK9cQ3UN4wbyKDRs'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfa-2239-7603-b044-da7d97aeb1d8-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú 29 de diciembre 2025'}, 'id': 'SbhlQnyt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1647, 'output_tokens': 32, 'total_tokens': 1679, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'clima en Lima Perú 29 de diciembre 2025', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.am1010ondalatina.com/articulo/2025/12/clima-hoy-en-lima-peru-el-pronostico-del-tiempo-para-este-lunes-29-diciembre-de-2025.php', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025 - Onda Latina AM 1010', 'content': '## Último Momento :. ## Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025. El pronóstico extendido durante la jornada.¿Cómo estará el cielo? ¿Cuál es la probabilidad de lluvias?... * 📘 Compartir en Facebook 🐦 Compartir en Twitter 💬 Compartir por WhatsApp 🔗 Copiar enlace. ### Comentarios. ### Deja tu comentario. ## Más Populares. ## 🔔 ¡Activa las Notificaciones! Mantente informado con las últimas novedades.', 'score': 0.90227455, 'raw_content': None}, {'url': 'https://rpp.pe/peru/actualidad/senamhi-pronostico-del-clima-hoy-lunes-29-de-diciembre-2025-noticia-1669539', 'title': 'SENAMHI: Pronóstico del clima hoy lunes 29 de diciembre 2025', 'content': 'Consulta el pronóstico del clima hoy en Lima y ciudades del Perú: temperatura actual, sensación térmica, radiación UV, probabilidad de lluvia y', 'score': 0.82492816, 'raw_content': None}, {'url': 'https://www.clarin.com/informacion-general/clima-hoy-lima-peru-pronostico-tiempo-lunes-29-diciembre-2025_0_HLjQ5uUfRs.html', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes ...', 'content': 'El pronóstico del tiempo para Lima, Perú indica que este lunes 29 de diciembre la temperatura máxima será de 24°C y la mínima de 18°C.', 'score': 0.8194462, 'raw_content': None}], 'response_time': 0.88, 'request_id': '22a8f2fa-7d71-456b-b018-3819630c2411'}", name='tavily_search', tool_call_id='SbhlQnyt'), AIMessage(content=[{'type': 'text', 'text': 'Para hoy, lunes 29 de diciembre de 2025, el pronóstico del tiempo en Lima, Perú, indica temperaturas moderadas propias de la temporada:\n\n*   **Temperatura máxima:** 24°C\n*   **Temperatura mínima:** 18°C\n\nSe recomienda estar atento a los reportes del SENAMHI durante el día para conocer variaciones en la radiación UV o condiciones específicas de nubosidad, que so ...
# llm: [AIMessage(content=[{'type': 'text', 'text': 'Para hoy, lunes 29 de diciembre de 2025, en Medellín, Colombia, el pronóstico indica una temperatura máxima de **26°C**. \n\nAl igual que en otras fechas de esta época, la ciudad suele mantener un clima templado característico, aunque es recomendable estar preparado para posibles cambios en la nubosidad o precipitaciones ocasionales, que son comunes en la región durante diciembre.', 'extras': {'signature': 'EjQKMgERTTIPH5UpyqBQuUvB2o8XyD7eNAER/OklxJCVHJn3rfnJoCp03bA1DyvjexLjwkcu'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfb-8d67-7da2-b083-bcc4bd8c63c0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3499, 'output_tokens': 86, 'total_tokens': 3585, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Cuál ciudad está más caliente?")]
thread = {"configurable": {"thread_id": "3"}} 

print("\n--- Pregunta 3: Comparación ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pregunta 3: Comparación ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content=[], additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa 29 de diciembre 2025"}'}, '__gemini_function_call_thought_signatures__': {'SbhlQnyt': 'EjQKMgERTTIP9tWrltwwAGWuEO32tsajxKkkoiRcov5g7uyJTIoJ/uJ7BK9cQ3UN4wbyKDRs'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfa-2239-7603-b044-da7d97aeb1d8-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú 29 de diciembre 2025'}, 'id': 'SbhlQnyt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1647, 'output_tokens': 32, 'total_tokens': 1679, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'clima en Lima Perú 29 de diciembre 2025', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.am1010ondalatina.com/articulo/2025/12/clima-hoy-en-lima-peru-el-pronostico-del-tiempo-para-este-lunes-29-diciembre-de-2025.php', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025 - Onda Latina AM 1010', 'content': '## Último Momento :. ## Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025. El pronóstico extendido durante la jornada.¿Cómo estará el cielo? ¿Cuál es la probabilidad de lluvias?... * 📘 Compartir en Facebook 🐦 Compartir en Twitter 💬 Compartir por WhatsApp 🔗 Copiar enlace. ### Comentarios. ### Deja tu comentario. ## Más Populares. ## 🔔 ¡Activa las Notificaciones! Mantente informado con las últimas novedades.', 'score': 0.90227455, 'raw_content': None}, {'url': 'https://rpp.pe/peru/actualidad/senamhi-pronostico-del-clima-hoy-lunes-29-de-diciembre-2025-noticia-1669539', 'title': 'SENAMHI: Pronóstico del clima hoy lunes 29 de diciembre 2025', 'content': 'Consulta el pronóstico del clima hoy en Lima y ciudades del Perú: temperatura actual, sensación térmica, radiación UV, probabilidad de lluvia y', 'score': 0.82492816, 'raw_content': None}, {'url': 'https://www.clarin.com/informacion-general/clima-hoy-lima-peru-pronostico-tiempo-lunes-29-diciembre-2025_0_HLjQ5uUfRs.html', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes ...', 'content': 'El pronóstico del tiempo para Lima, Perú indica que este lunes 29 de diciembre la temperatura máxima será de 24°C y la mínima de 18°C.', 'score': 0.8194462, 'raw_content': None}], 'response_time': 0.88, 'request_id': '22a8f2fa-7d71-456b-b018-3819630c2411'}", name='tavily_search', tool_call_id='SbhlQnyt'), AIMessage(content=[{'type': 'text', 'text': 'Para hoy, lunes 29 de diciembre de 2025, el pronóstico del tiempo en Lima, Perú, indica temperaturas moderadas propias de la temporada:\n\n*   **Temperatura máxima:** 24°C\n*   **Temperatura mínima:** 18°C\n\nSe recomienda estar atento a los reportes del SENAMHI durante el día para conocer variaciones en la radiación UV o condiciones específicas de nubosidad, que so ...
# llm: [AIMessage(content=[{'type': 'text', 'text': 'Comparando los datos para este lunes 29 de diciembre de 2025:\n\n*   **Medellín:** tiene una temperatura máxima de **26°C**.\n*   **Lima:** tiene una temperatura máxima de **24°C**.\n\nPor lo tanto, **Medellín está más caliente** que Lima hoy, con una diferencia de 2 grados en su temperatura máxima.', 'extras': {'signature': 'EjQKMgERTTIPYBzjl2cvUB+EWSSh7k/z0aE9u/ER9wHi/Ro3Sd6q6YdP6CSvPBSZmS36zo+e'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfe-7640-78f0-8cb9-39849f7be080-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3593, 'output_tokens': 84, 'total_tokens': 3677, 'input_token_details': {'cache_read': 0}})]

# %%
messages = [HumanMessage(content="Cuál ciudad está más caliente?")]
thread = {"configurable": {"thread_id": "3"}} 

print("\n--- Pergunta 4: Comparación ---")
for event in abot.graph.stream({"messages": messages}, thread):
    for k, v in event.items():
        if k in ("llm", "action"):
            print(f"{k}: {v['messages']}")
# Out:
# --- Pergunta 4: Comparación ---
# Mensajes enviados al modelo: [SystemMessage(content='\nEres un asistente de investigación inteligente. Usa el motor de búsqueda (tavily_search_results_json) para buscar información.\nTienes permiso para realizar múltiples llamadas a la herramienta (de forma conjunta o en secuencia).\nBusca información únicamente cuando tengas certeza de qué buscar.\nSi necesitas más detalles para formular una pregunta de seguimiento, tienes permiso para hacerlo.\nCuando se te solicite comparar información (por ejemplo: cuál es más caliente, más grande, etc.), utiliza la información del historial de la conversación y los resultados de las herramientas.\n', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), HumanMessage(content='Cómo está el clima en Lima - Perú hoy (29 de diciembre de 2025)?', additional_kwargs={}, response_metadata={}), AIMessage(content=[], additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "clima en Lima Per\\u00fa 29 de diciembre 2025"}'}, '__gemini_function_call_thought_signatures__': {'SbhlQnyt': 'EjQKMgERTTIP9tWrltwwAGWuEO32tsajxKkkoiRcov5g7uyJTIoJ/uJ7BK9cQ3UN4wbyKDRs'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfa-2239-7603-b044-da7d97aeb1d8-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'clima en Lima Perú 29 de diciembre 2025'}, 'id': 'SbhlQnyt', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1647, 'output_tokens': 32, 'total_tokens': 1679, 'input_token_details': {'cache_read': 0}}), ToolMessage(content="{'query': 'clima en Lima Perú 29 de diciembre 2025', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.am1010ondalatina.com/articulo/2025/12/clima-hoy-en-lima-peru-el-pronostico-del-tiempo-para-este-lunes-29-diciembre-de-2025.php', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025 - Onda Latina AM 1010', 'content': '## Último Momento :. ## Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes 29 diciembre de 2025. El pronóstico extendido durante la jornada.¿Cómo estará el cielo? ¿Cuál es la probabilidad de lluvias?... * 📘 Compartir en Facebook 🐦 Compartir en Twitter 💬 Compartir por WhatsApp 🔗 Copiar enlace. ### Comentarios. ### Deja tu comentario. ## Más Populares. ## 🔔 ¡Activa las Notificaciones! Mantente informado con las últimas novedades.', 'score': 0.90227455, 'raw_content': None}, {'url': 'https://rpp.pe/peru/actualidad/senamhi-pronostico-del-clima-hoy-lunes-29-de-diciembre-2025-noticia-1669539', 'title': 'SENAMHI: Pronóstico del clima hoy lunes 29 de diciembre 2025', 'content': 'Consulta el pronóstico del clima hoy en Lima y ciudades del Perú: temperatura actual, sensación térmica, radiación UV, probabilidad de lluvia y', 'score': 0.82492816, 'raw_content': None}, {'url': 'https://www.clarin.com/informacion-general/clima-hoy-lima-peru-pronostico-tiempo-lunes-29-diciembre-2025_0_HLjQ5uUfRs.html', 'title': 'Clima hoy en Lima, Perú: el pronóstico del tiempo para este lunes ...', 'content': 'El pronóstico del tiempo para Lima, Perú indica que este lunes 29 de diciembre la temperatura máxima será de 24°C y la mínima de 18°C.', 'score': 0.8194462, 'raw_content': None}], 'response_time': 0.88, 'request_id': '22a8f2fa-7d71-456b-b018-3819630c2411'}", name='tavily_search', tool_call_id='SbhlQnyt'), AIMessage(content=[{'type': 'text', 'text': 'Para hoy, lunes 29 de diciembre de 2025, el pronóstico del tiempo en Lima, Perú, indica temperaturas moderadas propias de la temporada:\n\n*   **Temperatura máxima:** 24°C\n*   **Temperatura mínima:** 18°C\n\nSe recomienda estar atento a los reportes del SENAMHI durante el día para conocer variaciones en la radiación UV o condiciones específicas de nubosidad, que so ...
# llm: [AIMessage(content=[{'type': 'text', 'text': 'Como mencioné anteriormente, comparando las temperaturas máximas pronosticadas para hoy, **Medellín está más caliente** que Lima.\n\nAquí tienes la comparación directa:\n*   **Medellín:** 26°C\n*   **Lima:** 24°C\n\nMedellín supera a Lima en la temperatura máxima por **2 grados centígrados**.', 'extras': {'signature': 'EjQKMgERTTIPz8N0jLAwc9lxVVo2tb3cIHZVbtGVD7lfuc4Yq+einPfboW83iS5/UaB+qD2n'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f4dfe-c5e9-7be1-8f4e-f31c3517440b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 3685, 'output_tokens': 79, 'total_tokens': 3764, 'input_token_details': {'cache_read': 0}})]
